# %% [markdown]
# #Assignment 03 Programing for AI
# **Name: Amir Khan**
#
# **Roll No: SP24-RAI-002**
#
# **Paper:** **Calibrated Language Model Fine-Tuning for In- and Out-of-Distribution Data**

# %% [markdown]
# #Cloning Model Code

# %%
# !git clone https://github.com/Lingkai-Kong/Calibrated-BERT-Fine-Tuning
# Out:
# Cloning into 'Calibrated-BERT-Fine-Tuning'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 48 (delta 20), reused 44 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (48/48), 20.43 MiB | 20.59 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# %cd /content/Calibrated-BERT-Fine-Tuning
# Out:
# /content/Calibrated-BERT-Fine-Tuning

# %% [markdown]
# #Fine Tuning Bert & Training with BERT base:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !CUDA_VISIBLE_DEVICES=0 python bert.py --dataset 20news-15 --seed 0
# Out:
# 2024-12-25 21:22:10.821105: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-25 21:22:10.854840: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-25 21:22:10.865126: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-25 21:22:10.888551: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-25 21:22:12.570073: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Namespace(lr=5e-05, train_batch_size=32, eval_batch_size=128, epochs=10, seed=0, dataset='20news-15', weight_decay=0.0, saved_dataset='n')
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space']
# 8763
# 5833
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch:   0% 0/10 [00:00<?, ?it/s]Epoch 1, Step 0, Loss = 2.722421169281006
# Epoch 1, Step 50, Loss = 1.8793070316314697
# Epoch 1, Step 100, Loss = 0.8967243432998657
# Epoch 1, Step 150, Loss = 0.8657031655311584
# Epoch 1, Step 200, Loss = 0.5230212211608887
# Epoch 1: Training Loss = 1.2464964882386003
# Validation Accuracy: 0.838562464346834
# Validation ECE: 0.05426071584224701
# Epoch:  10% 1/10 [03:16<29:29, 196.56s/it]Epoch 2, Step 0, Loss = 0.37011444568634033
# Epoch 2, Step 50, Loss = 0.30432167649269104
# Epoch 2, Step 100, Loss = 0.26787713170051575
# Epoch 2, Step 150, Loss = 0.7097916603088379
# Epoch 2, Step 200, Loss = 0.1120828166604042
# Epoch 2: Training Loss = 0.36760807330296796
# Validation Accuracy: 0.8750713063320023
# Validation ECE: 0.035604286938905716
# Epoch:  20% 2/10 [06:35<26:23, 197.92s/it]Epoch 3, Step 0, Loss = 0.30885910987854004
# Epoch 3, Step 50, Loss = 0.19305817782878876
# Epoch 3, Step 100, Loss = 0.051384780555963516
# Epoch 3, Step 150, Loss = 0.359980046749115
# Epoch 3, Step 200, Loss = 0.10554859787225723
# Epoch 3: Training Loss = 0.1473619218661704
# Validation Accuracy: 0.8984597832287508
# Validation ECE: 0.03648510202765465
# Epoch:  30% 3/10 [09:54<23:08, 198.32s/it]Epoch 4, Step 0, Loss = 0.08237146586179733
# Epoch 4, Step 50, Loss = 0.04024285450577736
# Epoch 4, Step 100, Loss = 0.2046414166688919
# Epoch 4, Step 150, Loss = 0.019415905699133873
# Epoch 4, Step 200, Loss = 0.027977420017123222
# Epoch 4: Training Loss = 0.09274589614096013
# Validation Accuracy: 0.9087278950370793
# Validation ECE: 0.04156613349914551
# Epoch:  40% 4/10 [13:12<19:50, 198.39s/it]Epoch 5, Step 0, Loss = 0.12080678343772888
# Epoch 5, Step 50, Loss = 0.14323672652244568
# Epoch 5, Step 100, Loss = 0.1461058259010315
# Epoch 5, Step 150, Loss = 0.020874928683042526
# Epoch 5, Step 200, Loss = 0.07757096737623215
# Epoch 5: Training Loss = 0.07032488294961778
# Validation Accuracy: 0.9098687963491158
# Validation ECE: 0.040523409843444824
# Epoch:  50% 5/10 [16:31<16:33, 198.65s/it]Epoch 6, Step 0, Loss = 0.019648464396595955
# Epoch 6, Step 50, Loss = 0.2459048330783844
# Epoch 6, Step 100, Loss = 0.015795256942510605
# Epoch 6, Step 150, Loss = 0.06765768676996231
# Epoch 6, Step 200, Loss = 0.018462030217051506
# Epoch 6: Training Loss = 0.06451178225688636
# Validation Accuracy: 0.9064460924130062
# Validation ECE: 0.04453035071492195
# Epoch:  60% 6/10 [19:44<13:06, 196.60s/it]Epoch 7, Step 0, Loss = 0.11519207805395126
# Epoch 7, Step 50, Loss = 0.10745768994092941
# Epoch 7, Step 100, Loss = 0.019834667444229126
# Epoch 7, Step 150, Loss = 0.13091954588890076
# Epoch 7, Step 200, Loss = 0.06013333052396774
# Epoch 7: Training Loss = 0.06255371637049724
# Validation Accuracy: 0.9070165430690246
# Validation ECE: 0.04414445906877518
# Epoch:  70% 7/10 [22:56<09:45, 195.19s/it]Epoch 8, Step 0, Loss = 0.02685108594596386
# Epoch 8, Step 50, Loss = 0.09516911208629608
# Epoch 8, Step 100, Loss = 0.24615323543548584
# Epoch 8, Step 150, Loss = 0.032161153852939606
# Epoch 8, Step 200, Loss = 0.045480046421289444
# Epoch 8: Training Loss = 0.06251101187768984
# Validation Accuracy: 0.908157444381061
# Validation ECE: 0.04318945109844208
# Epoch:  80% 8/10 [26:09<06:28, 194.26s/it]Epoch 9, Step 0, Loss = 0.15982823073863983
# Epoch 9, Step 50, Loss = 0.021534891799092293
# Epoch 9, Step 100, Loss = 0.12714698910713196
# Epoch 9, Step 150, Loss = 0.023643778637051582
# Epoch 9, Step 200, Loss = 0.1601260006427765
# Epoch 9: Training Loss = 0.0594381418036805
# Validation Accuracy: 0.908157444381061
# Validation ECE: 0.04320012032985687
# Epoch:  90% 9/10 [29:21<03:13, 193.63s/it]Epoch 10, Step 0, Loss = 0.13412103056907654
# Epoch 10, Step 50, Loss = 0.027767902240157127
# Epoch 10, Step 100, Loss = 0.02159491740167141
# Epoch 10, Step 150, Loss = 0.018026821315288544
# Epoch 10, Step 200, Loss = 0.022196173667907715
# Epoch 10: Training Loss = 0.060813882142644035
# Validation Accuracy: 0.908157444381061
# Validation ECE: 0.04321231693029404
# Epoch: 100% 10/10 [32:33<00:00, 195.36s/it]
# Test Accuracy: 0.8702211554945997
# Test ECE: 0.06441044807434082

# %% [markdown]
# #Evaluation with BERT base

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python test.py --model base --in_dataset 20news-15 --out_dataset 20news-5 --index 0
# Out:
# 2024-12-25 23:24:50.722026: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-25 23:24:50.741633: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-25 23:24:50.747475: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-25 23:24:50.761660: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-25 23:24:51.865958: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Load Tekenizer
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space']
# 8763
# 5833
# ['soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']
# 1699
# Val Accuracy: 0.9098687963491158
# ECE on Val data: 0.04052339866757393
# Test Accuracy: 0.8705640322304131
# ECE on Test data: 0.06300012022256851
# OOD detection, NBAUCC 0.5: 0.05142957390733057
# misclassification detection, NBAUCC 0.5: 0.05238851924554827
# OOD detection, NBAUCC 1.0: 0.18159819773384547
# misclassification detection, NBAUCC 1.0: 0.2370919187282889

# %% [markdown]
# #Evaluation with temperature scaling [1] (based on the trained BERT-base model)

# %%
# !python test.py --model temperature --in_dataset 20news-15 --out_dataset 20news-5 --index 0
# Out:
# 2024-12-25 23:03:53.540146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-25 23:03:53.560399: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-25 23:03:53.566815: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-25 23:03:53.581109: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-25 23:03:54.648405: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space']
# 8763
# 5833
# ['soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']
# 1699
# Before temperature - NLL: 0.379, ECE: 0.041
# Optimal temperature: 1.008
# After temperature - NLL: 0.378, ECE: 0.040
# Val Accuracy: 0.9098687963491158
# ECE on Val data: 0.03956414759159088
# Test Accuracy: 0.8705640322304131
# ECE on Test data: 0.06188554689288139
# OOD detection, NBAUCC 0.5: 0.05221594408977882
# misclassification detection, NBAUCC 0.5: 0.05332671282702438
# OOD detection, NBAUCC 1.0: 0.18273559611582524
# misclassification detection, NBAUCC 1.0: 0.23849705521172324

# %% [markdown]
# #Evaluation with MC-dropout [2] (based on the trained BERT-base model)

# %%
# !python test.py --model mc-dropout --in_dataset 20news-15 --out_dataset 20news-5 --eva_iter 10 --index 0
# Out:
# 2024-12-25 23:09:43.659714: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-25 23:09:43.691289: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-25 23:09:43.702673: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-25 23:09:43.725205: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-25 23:09:45.280377: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space']
# 8763
# 5833
# ['soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']
# 1699
# Val Accuracy: 0.9098687963491158
# ECE on Val data: 0.02568880282342434
# Test Accuracy: 0.8714212240699468
# ECE on Test data: 0.042229361832141876
# OOD detection, NBAUCC 0.5: 0.06579236230646086
# misclassification detection, NBAUCC 0.5: 0.07481582898542176
# OOD detection, NBAUCC 1.0: 0.1971190854682696
# misclassification detection, NBAUCC 1.0: 0.2703141795479486

# %%
# !cp -r /content/Calibrated-BERT-Fine-Tuning /content/drive/MyDrive/bert_fine_tuning

# %% [markdown]
# #Performance Metrices
# ![image.png](data:image/png;base64,...)
